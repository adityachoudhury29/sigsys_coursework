# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
from scipy import signal
from scipy.fft import fft,ifft

# %%
#1
time=np.linspace(0,50,100)
amp=10*np.sin(400*np.pi*time)+5*np.sin(800*np.pi*time)+12*np.sin(600*np.pi*time)
plt.plot(time,amp)

# %%
y = fft(amp)
mag = np.abs(y)
phase = np.angle(y)

# %%
freq = np.arange(0, 100)
plt.plot(freq, mag)

# %%
plt.plot(freq,phase)

# %%
#2a
def just_plot(y):
    plt.plot(t,y)

def fft_plot(amp):
    y = fft(amp)
    mag = np.abs(y)
    freq = np.arange(0, 100)
    plt.plot(freq, mag)
    
def ifft_plot(y):
    g = ifft(y)
    plt.figure()
    plt.plot(t, np.real(g))

t=np.linspace(0,50,100)
f1,f2,f3=1,4,7

fn1=3*np.sin(2*np.pi*f1*t)+np.sin(2*np.pi*f2*t)+0.5*np.sin(2*np.pi*f3*t)
y1=fft(fn1)

just_plot(fn1)
ifft_plot(y1)

# %%
#2b
a,b,f=2,3,4
fn1=a*np.sin(2*np.pi*f*t)+b
y1=fft(fn1)

just_plot(fn1)
ifft_plot(y1)

# %%
#2c
a,phi,f=2,10,4
fn1=a*np.cos(2*np.pi*f*t+phi)
y1=fft(fn1)

just_plot(fn1)
ifft_plot(y1)

# %%
#2d
def csum():
    s=0
    for i in range(100000):
        s+=(i*np.sin((2*i+1)*np.pi*t)/(2*i+1))
    return s

fn1=(4/np.pi)*csum()
y1=fft(fn1)

just_plot(fn1)
ifft_plot(y1)
